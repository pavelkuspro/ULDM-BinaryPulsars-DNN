# %% [markdown]
# Upload the basic notebook

# %%
# %%capture
# %run foundation_notebook.ipynb

# %%
print("Notebook run successfully!")
# Out:
# Notebook run successfully!

# %%
import pickle

# %%
snr_range = range(0, 35 + 1, 1)

# %% [markdown]
# # 9. Evaluation (part 2)

# %% [markdown]
# ## 9.1 Upload data: accuracy vs epoch

# %%
import pickle

with open('store/files/binary_classifier_all_spins/accuracy_vs_S_allspins_r1_C.pkl', 'rb') as f:
    data = pickle.load(f)
accuracy_s0l_r1_C = data['accuracy_s0l_r1_C']
accuracy_s0q_r1_C = data['accuracy_s0q_r1_C']
accuracy_s1_r1_C  = data['accuracy_s1_r1_C']
accuracy_s2_r1_C  = data['accuracy_s2_r1_C']

with open('store/files/binary_classifier_all_spins/accuracy_vs_S_allspins_r2_C.pkl', 'rb') as f:
    data = pickle.load(f)
accuracy_s0l_r2_C = data['accuracy_s0l_r2_C']
accuracy_s0q_r2_C = data['accuracy_s0q_r2_C']
accuracy_s1_r2_C  = data['accuracy_s1_r2_C']
accuracy_s2_r2_C  = data['accuracy_s2_r2_C']

with open('store/files/binary_classifier_all_spins/accuracy_vs_S_allspins_r3_C.pkl', 'rb') as f:
    data = pickle.load(f)
accuracy_s0l_r3_C = data['accuracy_s0l_r3_C']
accuracy_s0q_r3_C = data['accuracy_s0q_r3_C']
accuracy_s1_r3_C  = data['accuracy_s1_r3_C']
accuracy_s2_r3_C  = data['accuracy_s2_r3_C']

with open('store/files/binary_classifier_all_spins/accuracy_vs_S_allspins_r4_C.pkl', 'rb') as f:
    data = pickle.load(f)
accuracy_s0l_r4_C = data['accuracy_s0l_r4_C']
accuracy_s0q_r4_C = data['accuracy_s0q_r4_C']
accuracy_s1_r4_C  = data['accuracy_s1_r4_C']
accuracy_s2_r4_C  = data['accuracy_s2_r4_C']

with open('store/files/binary_classifier_all_spins/accuracy_vs_S_allspins_r5_C.pkl', 'rb') as f:
    data = pickle.load(f)
accuracy_s0l_r5_C = data['accuracy_s0l_r5_C']
accuracy_s0q_r5_C = data['accuracy_s0q_r5_C']
accuracy_s1_r5_C  = data['accuracy_s1_r5_C']
accuracy_s2_r5_C  = data['accuracy_s2_r5_C']

with open('store/files/binary_classifier_all_spins/accuracy_vs_S_allspins_r6_C.pkl', 'rb') as f:
    data = pickle.load(f)
accuracy_s0l_r6_C = data['accuracy_s0l_r6_C']
accuracy_s0q_r6_C = data['accuracy_s0q_r6_C']
accuracy_s1_r6_C  = data['accuracy_s1_r6_C']
accuracy_s2_r6_C  = data['accuracy_s2_r6_C']

with open('store/files/binary_classifier_all_spins/accuracy_vs_S_allspins_r7_C.pkl', 'rb') as f:
    data = pickle.load(f)
accuracy_s0l_r7_C = data['accuracy_s0l_r7_C']
accuracy_s0q_r7_C = data['accuracy_s0q_r7_C']
accuracy_s1_r7_C  = data['accuracy_s1_r7_C']
accuracy_s2_r7_C  = data['accuracy_s2_r7_C']

with open('store/files/binary_classifier_all_spins/accuracy_vs_S_allspins_r8_C.pkl', 'rb') as f:
    data = pickle.load(f)
accuracy_s0l_r8_C = data['accuracy_s0l_r8_C']
accuracy_s0q_r8_C = data['accuracy_s0q_r8_C']
accuracy_s1_r8_C  = data['accuracy_s1_r8_C']
accuracy_s2_r8_C  = data['accuracy_s2_r8_C']

with open('store/files/binary_classifier_all_spins/accuracy_vs_S_allspins_r9_C.pkl', 'rb') as f:
    data = pickle.load(f)
accuracy_s0l_r9_C = data['accuracy_s0l_r9_C']
accuracy_s0q_r9_C = data['accuracy_s0q_r9_C']
accuracy_s1_r9_C  = data['accuracy_s1_r9_C']
accuracy_s2_r9_C  = data['accuracy_s2_r9_C']

with open('store/files/binary_classifier_all_spins/accuracy_vs_S_allspins_r10c2_C.pkl', 'rb') as f:
    data = pickle.load(f)
accuracy_s0l_r10_C = data['accuracy_s0l_r10_C']
accuracy_s0q_r10_C = data['accuracy_s0q_r10_C']
accuracy_s1_r10_C  = data['accuracy_s1_r10_C']
accuracy_s2_r10_C  = data['accuracy_s2_r10_C']

# %%
import matplotlib.pyplot as plt

# Create a 2x2 subplot
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Plot for the first subplot (s0l)
axs[0, 0].plot(0, accuracy_s0l_r1_C[0], "*", color="red")
axs[0, 0].plot(snr_range[1:], accuracy_s0l_r1_C[1:], "*", color="red", label="CL-P1")

axs[0, 0].plot(0, accuracy_s0l_r2_C[0], "*", color="green")
axs[0, 0].plot(snr_range[1:], accuracy_s0l_r2_C[1:], "--", color="green", label="CL-P2")

axs[0, 0].plot(0, accuracy_s0l_r3_C[0], "*", color="blue")
axs[0, 0].plot(snr_range[1:], accuracy_s0l_r3_C[1:], "-.", color="blue", label="CL-P3")

axs[0, 0].plot(0, accuracy_s0l_r4_C[0], "*", color="purple")
axs[0, 0].plot(snr_range[1:], accuracy_s0l_r4_C[1:], "-*", color="purple", label="CL-P4")

axs[0, 0].plot(0, accuracy_s0l_r5_C[0], "*", color="orange")
axs[0, 0].plot(snr_range[1:], accuracy_s0l_r5_C[1:], ":", color="orange", label="CL-P5")

axs[0, 0].plot(0, accuracy_s0l_r6_C[0], "*", color="gold")
axs[0, 0].plot(snr_range[1:], accuracy_s0l_r6_C[1:], "-", color="gold", label="CL-P6")

axs[0, 0].plot(0, accuracy_s0l_r7_C[0], "*", color="brown")
axs[0, 0].plot(snr_range[1:], accuracy_s0l_r7_C[1:], "-", color="brown", label="CL-P7")

axs[0, 0].plot(0, accuracy_s0l_r8_C[0], "*", color="grey")
axs[0, 0].plot(snr_range[1:], accuracy_s0l_r8_C[1:], "-", color="grey", label="CL-P8")

axs[0, 0].plot(0, accuracy_s0l_r9_C[0], "*", color="black")
axs[0, 0].plot(snr_range[1:], accuracy_s0l_r9_C[1:], "--", lw = 5, color="black", label="CL-P9")

#axs[0, 0].set_title("Spin-0 (L), Noise type C")

axs[0, 0].text(14, 0.13, 'Noise type C', fontsize=15, color="black")
axs[0, 0].text(15, 0.03, 'Spin-0 (L)', fontsize=15, color="black")


axs[0, 0].set_xlabel(r"$S$")
axs[0, 0].set_ylabel("Accuracy")
axs[0, 0].legend()

# Plot for the second subplot (s0q)
axs[0, 1].plot(0, accuracy_s0q_r1_C[0], "*", color="red")
axs[0, 1].plot(snr_range[1:], accuracy_s0q_r1_C[1:], "*", color="red", label="CL-P1")

axs[0, 1].plot(0, accuracy_s0q_r2_C[0], "*", color="green")
axs[0, 1].plot(snr_range[1:], accuracy_s0q_r2_C[1:], "--", color="green", label="CL-P2")

axs[0, 1].plot(0, accuracy_s0q_r3_C[0], "*", color="blue")
axs[0, 1].plot(snr_range[1:], accuracy_s0q_r3_C[1:], "-.", color="blue", label="CL-P3")

axs[0, 1].plot(0, accuracy_s0q_r4_C[0], "*", color="purple")
axs[0, 1].plot(snr_range[1:], accuracy_s0q_r4_C[1:], "-*", color="purple", label="CL-P4")

axs[0, 1].plot(0, accuracy_s0q_r5_C[0], "*", color="orange")
axs[0, 1].plot(snr_range[1:], accuracy_s0q_r5_C[1:], ":", color="orange", label="CL-P5")

axs[0, 1].plot(0, accuracy_s0q_r6_C[0], "*", color="gold")
axs[0, 1].plot(snr_range[1:], accuracy_s0q_r6_C[1:], "-", color="gold", label="CL-P6")

axs[0, 1].plot(0, accuracy_s0q_r7_C[0], "*", color="grey")
axs[0, 1].plot(snr_range[1:], accuracy_s0q_r7_C[1:], "-", color="grey", label="CL-P7")

axs[0, 1].plot(0, accuracy_s0q_r8_C[0], "*", color="grey")
axs[0, 1].plot(snr_range[1:], accuracy_s0q_r8_C[1:], "-", color="grey", label="CL-P8")

axs[0, 1].plot(0, accuracy_s0q_r9_C[0], "*", color="black")
axs[0, 1].plot(snr_range[1:], accuracy_s0q_r9_C[1:], "--", lw = 5, color="black", label="CL-P9")

#axs[0, 1].set_title("Spin-0 (Q), Noise type C")

axs[0, 1].text(14, 0.13, 'Noise type C', fontsize=15, color="black")
axs[0, 1].text(15, 0.03, 'Spin-0 (Q)', fontsize=15, color="black")

axs[0, 1].set_xlabel(r"$S$")
axs[0, 1].set_ylabel("Accuracy")
axs[0, 1].legend()

# Plot for the third subplot (s1)
axs[1, 0].plot(0, accuracy_s1_r1_C[0], "*", color="red")
axs[1, 0].plot(snr_range[1:], accuracy_s1_r1_C[1:], "*", color="red", label="CL-P1")

axs[1, 0].plot(0, accuracy_s1_r2_C[0], "*", color="green")
axs[1, 0].plot(snr_range[1:], accuracy_s1_r2_C[1:], "--", color="green", label="CL-P2")

axs[1, 0].plot(0, accuracy_s1_r3_C[0], "*", color="blue")
axs[1, 0].plot(snr_range[1:], accuracy_s1_r3_C[1:], "-.", color="blue", label="CL-P3")

axs[1, 0].plot(0, accuracy_s1_r4_C[0], "*", color="purple")
axs[1, 0].plot(snr_range[1:], accuracy_s1_r4_C[1:], "-*", color="purple", label="CL-P4")

axs[1, 0].plot(0, accuracy_s1_r5_C[0], "*", color="orange")
axs[1, 0].plot(snr_range[1:], accuracy_s1_r5_C[1:], ":", color="orange", label="CL-P5")

axs[1, 0].plot(0, accuracy_s1_r6_C[0], "*", color="gold")
axs[1, 0].plot(snr_range[1:], accuracy_s1_r6_C[1:], "-", color="gold", label="CL-P6")

axs[1, 0].plot(0, accuracy_s1_r7_C[0], "*", color="brown")
axs[1, 0].plot(snr_range[1:], accuracy_s1_r7_C[1:], "-", color="brown", label="CL-P7")

axs[1, 0].plot(0, accuracy_s1_r8_C[0], "*", color="grey")
axs[1, 0].plot(snr_range[1:], accuracy_s1_r8_C[1:], "-", color="grey", label="CL-P8")

axs[1, 0].plot(0, accuracy_s1_r9_C[0], "*", color="black")
axs[1, 0].plot(snr_range[1:], accuracy_s1_r9_C[1:], "--", lw = 5, color="black", label="CL-P9")

#axs[1, 0].set_title("Spin-1, Noise type C")

axs[1, 0].text(14, 0.13, 'Noise type C', fontsize=15, color="black")
axs[1, 0].text(17, 0.03, 'Spin-1', fontsize=15, color="black")

axs[1, 0].set_xlabel(r"$S$")
axs[1, 0].set_ylabel("Accuracy")
axs[1, 0].legend()

# Plot for the fourth subplot (s2)
axs[1, 1].plot(0, accuracy_s2_r1_C[0], "*", color="red")
axs[1, 1].plot(snr_range[1:], accuracy_s2_r1_C[1:], "*", color="red", label="CL-P1")

axs[1, 1].plot(0, accuracy_s2_r2_C[0], "*", color="green")
axs[1, 1].plot(snr_range[1:], accuracy_s2_r2_C[1:], "--", color="green", label="CL-P2")

axs[1, 1].plot(0, accuracy_s2_r3_C[0], "*", color="blue")
axs[1, 1].plot(snr_range[1:], accuracy_s2_r3_C[1:], "-.", color="blue", label="CL-P3")

axs[1, 1].plot(0, accuracy_s2_r4_C[0], "*", color="purple")
axs[1, 1].plot(snr_range[1:], accuracy_s2_r4_C[1:], "-*", color="purple", label="CL-P4")

axs[1, 1].plot(0, accuracy_s2_r5_C[0], "*", color="orange")
axs[1, 1].plot(snr_range[1:], accuracy_s2_r5_C[1:], ":", color="orange", label="CL-P5")

axs[1, 1].plot(0, accuracy_s2_r6_C[0], "*", color="gold")
axs[1, 1].plot(snr_range[1:], accuracy_s2_r6_C[1:], "-", color="gold", label="CL-P6")

axs[1, 1].plot(0, accuracy_s2_r7_C[0], "*", color="brown")
axs[1, 1].plot(snr_range[1:], accuracy_s2_r7_C[1:], "-", color="brown", label="CL-P7")

axs[1, 1].plot(0, accuracy_s2_r8_C[0], "*", color="grey")
axs[1, 1].plot(snr_range[1:], accuracy_s2_r8_C[1:], "-", color="grey", label="CL-P8")

axs[1, 1].plot(0, accuracy_s2_r9_C[0], "*", color="black")
axs[1, 1].plot(snr_range[1:], accuracy_s2_r9_C[1:], "--", lw = 5, color="black", label="CL-P9")

#axs[1, 1].set_title("Spin-2, Noise type C")

axs[1, 1].text(14, 0.13, 'Noise type C', fontsize=15, color="black")
axs[1, 1].text(17, 0.03, 'Spin-2', fontsize=15, color="black")

axs[1, 1].set_xlabel(r"$S$")
axs[1, 1].set_ylabel("Accuracy")
axs[1, 1].legend()

# Adjust layout for better spacing
plt.tight_layout()

plt.savefig("store/plots/binary_classifier_allspins/1_accuracy_vs_S_C_binaryclassifier_allspins.png", dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(0, accuracy_s0l_r9_C[0], "*", color = "purple", alpha = 0.5)
plt.plot(snr_range[1:], accuracy_s0l_r9_C[1:], "*", color = "purple", label = "CL-P9, S0(L)", alpha = 0.5)

plt.plot(0, accuracy_s0q_r9_C[0], "*", color = "gold", alpha = 0.5)
plt.plot(snr_range[1:], accuracy_s0q_r9_C[1:], "*", color = "gold", label = "CL-P9, S0(Q)", alpha = 0.5)

plt.plot(0, accuracy_s1_r9_C[0], "*", color = "brown", alpha = 0.5)
plt.plot(snr_range[1:], accuracy_s1_r9_C[1:], "*", color = "brown", label = "CL-P9, S1", alpha = 0.5)

plt.plot(0, accuracy_s2_r9_C[0], "*", color = "black", alpha = 0.5)
plt.plot(snr_range[1:], accuracy_s2_r9_C[1:], "*", color = "black", label = "CL-P9, S2", alpha = 0.5)

plt.axvline(x=14, color='grey', linestyle='--', linewidth=2, alpha = 0.5)



plt.plot(0, accuracy_s0l_r10_C[0], "o", ms = 6, color = "purple", alpha = 1)
plt.plot(snr_range[1:], accuracy_s0l_r10_C[1:], "-o", ms = 6, lw = 3, color = "purple", label = "CL-P10, S0(L)", alpha = 1)

plt.plot(0, accuracy_s0q_r10_C[0], "o", ms = 6, color = "gold", alpha = 1)
plt.plot(snr_range[1:], accuracy_s0q_r10_C[1:], "-o", ms = 6, lw = 3, color = "gold", label = "CL-P10, S0(Q)", alpha = 1)

plt.plot(0, accuracy_s1_r10_C[0], "o", ms = 6, color = "brown", alpha = 1)
plt.plot(snr_range[1:], accuracy_s1_r10_C[1:], "-o", ms = 6, lw = 3, color = "brown", label = "CL-P10, S1", alpha = 1)

plt.plot(0, accuracy_s2_r10_C[0], "o", ms = 6, color = "black", alpha = 1)
plt.plot(snr_range[1:], accuracy_s2_r10_C[1:], "-o", ms = 6, lw = 3, color = "black", label = "CL-P10, S2", alpha = 1)

plt.axvline(x=11, color='black', linestyle=':', linewidth=2, alpha = 0.5)

plt.xlabel(r"$S$") 
plt.ylabel("Accuracy") 

plt.text(28.5, 0.3, 'Noise type C', fontsize=14, color="black")

plt.legend(ncol = 2, loc = "lower right", fontsize = 13)

plt.savefig("store/plots/binary_classifier_allspins/2_accuracy_vs_S_C_binaryclassifier_allspins_round9and10.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
s0l_snr_C  = np.array(snr_range[1:])[np.round(np.array(accuracy_s0l_r10_C[1:]),2) >= 0.99][0]
s0l_prob_C = np.array(accuracy_s0l_r10_C[1:])[np.round(np.array(accuracy_s0l_r10_C[1:]),2) >= 0.99][0]

print(s0l_snr_C, "    ", s0l_prob_C)
# Out:
# 18      0.9850000143051147

# %%
# compute the lambda value when mass, r, upsilon and SNR are given

def threshold_lambda_spin0l(m, r, upsasc, snr):

    m_val = m.to(u.eV).value
    omegb_ev_val =omega_b_ev.value
    k = m_val / omegb_ev_val
    psi =  np.array(psi_i(omega_b, Tasc, TOA_sim_array))

    q_vec = residuum_s0l(1, x, m, rhoDM, r, omega_b_ev, psi, upsasc)
    q_len = np.sqrt( np.dot(q_vec,q_vec) )

    lamb = snr * noise.to(u.s) / q_len.to(u.s)

    return lamb

# %%
# considered mass interval
expon = np.linspace(-22, -21, 10) 
mass_list_short = 10**expon * u.eV

print(mass_list_short)
# Out:
# [1.00000000e-22 1.29154967e-22 1.66810054e-22 2.15443469e-22
#  2.78255940e-22 3.59381366e-22 4.64158883e-22 5.99484250e-22
#  7.74263683e-22 1.00000000e-21] eV

# %%
# a choice of DM phase and amplitude
upsasc_ex, r_ex = np.pi/4, 1 / np.sqrt(2)

# here, SNR is such that accuracy is 99%
lamb_s0l_array_099_C = []
for m in np.array(mass_list_short)*u.eV:
    lamb = np.array(threshold_lambda_spin0l(m, r_ex, upsasc_ex, s0l_snr_C))
    lamb_s0l_array_099_C.append(lamb)
lamb_s0l_array_099_C = np.array(lamb_s0l_array_099_C)

# %%
lamb_bayes_sensitivity_s0l_short = np.array([lambda_s0l(x, omega_b, m, rhoDM, r_ex, upsasc_ex) for m in  np.array(mass_list_short)*u.eV ])

# %%
plt.figure(figsize=(10, 6))

# Plot autoencoder (99%)
plt.plot(np.array(mass_list_short) * u.eV, lamb_s0l_array_099_C, "*--",  markersize = 10, color='black', label="B-CNN: 99% Accuracy, C")

plt.plot(np.array(mass_list_short) * u.eV, lamb_bayes_sensitivity_s0l_short, marker="s", linestyle='--', color='green', label="Bayes: Spin-0 (L) + White noise")

# Logarithmic scale for both axes
plt.xscale('log')
plt.yscale('log')

# Add gridlines for better readability on log scale
plt.grid(True, which="both", linestyle='--', linewidth=0.5)

# Set axis labels with clear descriptions
plt.xlabel(r'$m$ (eV)', fontsize=16)
plt.ylabel(r'$|\lambda|$ (1)', fontsize=16)

# Set tick label sizes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Customize the legend for better clarity
plt.legend(loc='upper left', fontsize=11)

median_s0l_C =round(np.mean(lamb_s0l_array_099_C / lamb_bayes_sensitivity_s0l_short))
plt.text(mass_list_short[-4].value, 1.5 * lamb_bayes_sensitivity_s0l_short[0], r"Bin-CNN/Bayes $\sim$" + str(median_s0l_C), fontsize=15, color="black")

plt.show()

# %%
s0q_snr_C  = np.array(snr_range[1:])[np.round(np.array(accuracy_s0q_r10_C[1:]),2) >= 0.99][0]
s0q_prob_C = np.array(accuracy_s0q_r10_C[1:])[np.round(np.array(accuracy_s0q_r10_C[1:]),2) >= 0.99][0]

print(s0q_snr_C, "    ", s0q_prob_C)
# Out:
# 19      0.9940000176429749

# %%
# compute the lambda value when mass, r, upsilon and SNR are given

def threshold_lambda_spin0q(m, r, upsasc, snr):

    m_val = m.to(u.eV).value
    omegb_ev_val =omega_b_ev.value
    k = m_val / omegb_ev_val
    psi =  np.array(psi_i(omega_b, Tasc, TOA_sim_array))

    q_vec = residuum_s0q(1, x, m, rhoDM, r, omega_b_ev, psi, upsasc)
    q_len = np.sqrt( np.dot(q_vec,q_vec) )

    lamb = snr * noise.to(u.s) / q_len.to(u.s)

    return lamb

# %%
# a choice of DM phase and amplitude
upsasc_ex, r_ex = np.pi/4, 1 / np.sqrt(2)

# here, SNR is such that accuracy is 99%
lamb_s0q_array_099_C = []
for m in np.array(mass_list_short)*u.eV:
    lamb = np.array(threshold_lambda_spin0q(m, r_ex, upsasc_ex, s0q_snr_C))
    lamb_s0q_array_099_C.append(lamb)
lamb_s0q_array_099_C = np.array(lamb_s0q_array_099_C)

# %%
lamb_bayes_sensitivity_s0q_short = np.array([lambda_s0q(x, omega_b, m, rhoDM, r_ex, upsasc_ex) for m in  np.array(mass_list_short)*u.eV ])

# %%
plt.figure(figsize=(10, 6))

# Plot autoencoder (99%)
plt.plot(np.array(mass_list_short) * u.eV, lamb_s0q_array_099_C, "*--",  markersize = 10, color='black', label="B-CNN: 99% Accuracy, C")

plt.plot(np.array(mass_list_short) * u.eV, lamb_bayes_sensitivity_s0q_short, marker="s", linestyle='--', color='green', label="Bayes: Spin-0 (Q) + White noise")

# Logarithmic scale for both axes
plt.xscale('log')
plt.yscale('log')

# Add gridlines for better readability on log scale
plt.grid(True, which="both", linestyle='--', linewidth=0.5)

# Set axis labels with clear descriptions
plt.xlabel(r'$m$ (eV)', fontsize=16)
plt.ylabel(r'$|\lambda|$ (1)', fontsize=16)

# Set tick label sizes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Customize the legend for better clarity
plt.legend(loc='upper left', fontsize=11)

median_s0q_C =round(np.mean(lamb_s0q_array_099_C / lamb_bayes_sensitivity_s0q_short))
plt.text(mass_list_short[-4].value, 1.5 * lamb_bayes_sensitivity_s0q_short[0], r"Bin-CNN/Bayes $\sim$" + str(median_s0q_C), fontsize=15, color="black")

plt.show()

# %%
s1_snr_C  = np.array(snr_range[1:])[np.round(np.array(accuracy_s1_r10_C[1:]),2) >= 0.99][0]
s1_prob_C = np.array(accuracy_s1_r10_C[1:])[np.round(np.array(accuracy_s1_r10_C[1:]),2) >= 0.99][0]

print(s1_snr_C, "    ", s1_prob_C)
# Out:
# 35      0.9879999756813049

# %%
# compute the lambda value when mass, r, upsilon and SNR are given

def threshold_lambda_spin1(m, r, upsilon, theta, phi, snr):

    m_val = m.to(u.eV).value
    omegb_ev_val =omega_b_ev.value
    k = m_val / omegb_ev_val
    psi =  np.array(psi_i(omega_b, Tasc, TOA_sim_array))

    q_vec = residuum_s1(1, x, m, r, omega_b_ev, psi, upsilon, theta, phi)
    q_len = np.sqrt( np.dot(q_vec,q_vec) )

    lamb = snr * noise.to(u.s) / q_len.to(u.s)

    return lamb

# %%
# a choice of DM phase and amplitude
upsasc_ex, theta_ex, phi_ex, r_ex = np.pi/3, np.pi/3, np.pi/3, 1 / np.sqrt(2)

# here, SNR is such that accuracy is 99%
lamb_s1_array_099_C = []
for m in np.array(mass_list_short)*u.eV:
    lamb = np.array(threshold_lambda_spin1(m, r_ex, upsasc_ex, theta_ex, phi_ex, s1_snr_C))
    lamb_s1_array_099_C.append(lamb)

lamb_s1_array_099_C = np.array(lamb_s1_array_099_C)

# %%
lamb_bayes_sensitivity_s1_short = np.array([lambda_s1(x, m, r_ex, omega_b_ev, upsasc_ex, theta_ex, phi_ex) for m in np.array(mass_list_short)*u.eV])

# %%
plt.figure(figsize=(10, 6))

# Plot autoencoder (99%)
plt.plot(np.array(mass_list_short) * u.eV, lamb_s1_array_099_C, marker="o", linestyle='-', color='black', label="B-CNN: 99% Accuracy, C")

# Plot simplistic Bayesian lines (spin 0, linear)
plt.plot(np.array(mass_list_short) * u.eV, lamb_bayes_sensitivity_s1_short, marker="s", linestyle='--', color='green', label="Bayes: Spin-1 + White noise")


# Logarithmic scale for both axes
plt.xscale('log')
plt.yscale('log')

# Add gridlines for better readability on log scale
plt.grid(True, which="both", linestyle='--', linewidth=0.5)

# Set axis labels with clear descriptions
plt.xlabel(r'$m$ (eV)', fontsize=16)
plt.ylabel(r'$|\lambda|$ (1)', fontsize=16)

# Set tick label sizes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Customize the legend for better clarity
plt.legend(loc='upper left', fontsize=11)

median_s1_C =round(np.mean(lamb_s1_array_099_C / lamb_bayes_sensitivity_s1_short))

plt.text(mass_list_short[-4].value, 1.5 * lamb_bayes_sensitivity_s1_short[0], r"Bin-CNN/Bayes $\sim$" + str(median_s1_C), fontsize=15, color="black")

plt.show()

# %%
s2_snr_C  = np.array(snr_range[1:])[np.round(np.array(accuracy_s2_r10_C[1:]),2) >= 0.99][0]
s2_prob_C = np.array(accuracy_s2_r10_C[1:])[np.round(np.array(accuracy_s2_r10_C[1:]),2) >= 0.99][0]

print(s2_snr_C, "    ", s2_prob_C)
# Out:
# 22      0.9850000143051147

# %%
# compute the lambda value when mass, r, upsilon and SNR are given

def threshold_lambda_spin2(m, r, upsilon, chi, eps_s, eps_t, snr):

    m_val = m.to(u.eV).value
    omegb_ev_val =omega_b_ev.value
    k = m_val / omegb_ev_val
    psi =  np.array(psi_i(omega_b, Tasc, TOA_sim_array))

    q_vec = residuum_s2(1, m, r, upsilon, chi, eps_s, eps_t, omega_b_ev, psi, omega)
    q_len = np.sqrt( np.dot(q_vec,q_vec) )

    lamb = snr * noise.to(u.s) / q_len.to(u.s)

    return lamb

# %%
# a choice of DM phase and amplitude
upsasc_ex, chi_ex, eps_s_ex, eps_t_ex, r_ex = np.pi/3, np.pi/3, 1 / np.sqrt(2), 1 / np.sqrt(2), 1 / np.sqrt(2)

lamb_s2_array_099_C = []
for m in np.array(mass_list_short)*u.eV:
    lamb = np.array(threshold_lambda_spin2(m, r_ex, upsasc_ex, chi_ex, eps_s_ex, eps_t_ex, s2_snr_C))
    lamb_s2_array_099_C.append(lamb)

lamb_s2_array_099_C = np.array(lamb_s2_array_099_C)

# %%
lamb_bayes_sensitivity_s2_short = np.array([lambda_s2(m, r_ex, upsasc_ex, chi_ex, eps_s_ex, eps_t_ex) for m in np.array(mass_list_short)*u.eV])

# %%
plt.figure(figsize=(10, 6))

# Plot autoencoder (99%)
plt.plot(np.array(mass_list_short) * u.eV, lamb_s2_array_099_C, marker="o", linestyle='-', color='black', label="B-CNN: 99% Accuracy, C")

# Plot simplistic Bayesian lines (spin 0, linear)
plt.plot(np.array(mass_list_short) * u.eV, lamb_bayes_sensitivity_s2_short, marker="s", linestyle='--', color='green', label="Bayes: Spin-2 + White noise")

# Logarithmic scale for both axes
plt.xscale('log')
plt.yscale('log')

# Add gridlines for better readability on log scale
plt.grid(True, which="both", linestyle='--', linewidth=0.5)

# Set axis labels with clear descriptions
plt.xlabel(r'$m$ (eV)', fontsize=16)
plt.ylabel(r'$|\lambda|$ (1)', fontsize=16)

# Set tick label sizes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Customize the legend for better clarity
plt.legend(loc='upper left', fontsize=11)

median_s2_C =round(np.mean(lamb_s2_array_099_C / lamb_bayes_sensitivity_s2_short))

plt.text(mass_list_short[-4].value, 1.5 * lamb_bayes_sensitivity_s2_short[0], r"Bin-CNN/Bayes $\sim$" + str(median_s2_C), fontsize=15, color="black")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u

# Create the 2x2 subplot layout
fig, axs = plt.subplots(2, 2, figsize=(12, 6))

# Plot 1: Spin-0 (L)
axs[0, 0].plot(np.array(mass_list_short) * u.eV, lamb_s0l_array_099_C, "*-", markersize=8, color='blue', label="B-CNN    Spin-0(L), Noise type C")
axs[0, 0].plot(np.array(mass_list_short) * u.eV, lamb_bayes_sensitivity_s0l_short, "s--", color='black', label="Bayes")
axs[0, 0].set_xscale('log')
axs[0, 0].set_yscale('log')
axs[0, 0].set_xlabel(r'$m$ (eV)', fontsize=12)
axs[0, 0].set_ylabel(r'$|\lambda|$', fontsize=12)
axs[0, 0].legend(fontsize=11, loc='upper left')
median_s0l_C = round(np.mean(lamb_s0l_array_099_C / lamb_bayes_sensitivity_s0l_short))
axs[0, 0].text(0.9*mass_list_short[-4].value, 1.5 * lamb_bayes_sensitivity_s0l_short[0], r"B-CNN/Bayes $\sim$" + str(median_s0l_C), fontsize=12, color = "blue")

# Plot 2: Spin-0 (Q)
axs[0, 1].plot(np.array(mass_list_short) * u.eV, lamb_s0q_array_099_C, "*--", markersize=8, color='blue', label="B-CNN    Spin-0(Q), Noise type C")
axs[0, 1].plot(np.array(mass_list_short) * u.eV, lamb_bayes_sensitivity_s0q_short, "s--", color='black', label="Bayes")
axs[0, 1].set_xscale('log')
axs[0, 1].set_yscale('log')
axs[0, 1].set_xlabel(r'$m$ (eV)', fontsize=12)
axs[0, 1].set_ylabel(r'$|\lambda|$', fontsize=12)
axs[0, 1].legend(fontsize=11, loc='upper left')
median_s0q_C = round(np.mean(lamb_s0q_array_099_C / lamb_bayes_sensitivity_s0q_short))
axs[0, 1].text(0.9*mass_list_short[-4].value, 1.5 * lamb_bayes_sensitivity_s0q_short[0], r"B-CNN/Bayes $\sim$" + str(median_s0q_C), fontsize=12, color = "blue")

# Plot 3: Spin-1
axs[1, 0].plot(np.array(mass_list_short) * u.eV, lamb_s1_array_099_C, "o-", color='blue', label="B-CNN    Spin-1, Noise type C")
axs[1, 0].plot(np.array(mass_list_short) * u.eV, lamb_bayes_sensitivity_s1_short, "s--", color='black', label="Bayes")
axs[1, 0].set_xscale('log')
axs[1, 0].set_yscale('log')
axs[1, 0].set_xlabel(r'$m$ (eV)', fontsize=12)
axs[1, 0].set_ylabel(r'$|\lambda|$', fontsize=12)
axs[1, 0].legend(fontsize=11, loc='upper left')
median_s1_C = round(np.mean(lamb_s1_array_099_C / lamb_bayes_sensitivity_s1_short))
axs[1, 0].text(0.9*mass_list_short[-4].value, 1.5 * lamb_bayes_sensitivity_s1_short[0], r"B-CNN/Bayes $\sim$" + str(median_s1_C), fontsize=12, color = "blue")

# Plot 4: Spin-2
axs[1, 1].plot(np.array(mass_list_short) * u.eV, lamb_s2_array_099_C, "o-", color='blue', label="B-CNN    Spin-2, Noise type C")
axs[1, 1].plot(np.array(mass_list_short) * u.eV, lamb_bayes_sensitivity_s2_short, "s--", color='black', label="Bayes")
axs[1, 1].set_xscale('log')
axs[1, 1].set_yscale('log')
axs[1, 1].set_xlabel(r'$m$ (eV)', fontsize=12)
axs[1, 1].set_ylabel(r'$|\lambda|$', fontsize=12)
axs[1, 1].legend(fontsize=11, loc='upper left')
median_s2_C = round(np.mean(lamb_s2_array_099_C / lamb_bayes_sensitivity_s2_short))
axs[1, 1].text(0.9*mass_list_short[-4].value, 1.5 * lamb_bayes_sensitivity_s2_short[0], r"B-CNN/Bayes $\sim$" + str(median_s2_C), fontsize=12, color = "blue")

# Adjust layout
plt.tight_layout()

plt.savefig("store/plots/binary_classifier_allspins/3_lambda_vs_m_A_binaryclassifier_all_spins.png", dpi=300, bbox_inches='tight')

plt.show()
